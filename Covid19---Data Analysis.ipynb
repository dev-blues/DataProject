# %%
import pandas as pd

# %%
df=pd.read_csv('covid_19_data.csv')

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df.shape
# Out:
# (321, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
#deleting the state column
df.drop(columns='State',inplace=True)

# %% [markdown]
# # Q1) Show the no. of confirmed,deaths and recovered cases in each region.

# %%
df.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
df.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
df.groupby('Region')['Confirmed','Deaths'].sum()
# Out:
# C:\Users\Dev\AppData\Local\Temp\ipykernel_10712\3945312351.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Region')['Confirmed','Deaths'].sum()
#                     Confirmed  Deaths
# Region
# Afghanistan              1939      60
# Albania                   766      30
# Algeria                  3848     444
# Andorra                   743      42
# Angola                     27       2
# ...                       ...     ...
# West Bank and Gaza        344       2
# Western Sahara              6       0
# Yemen                       6       0
# Zambia                     97       3
# Zimbabwe                   32       4
#
# [187 rows x 2 columns]

# %% [markdown]
# # Q2) Remove all the records where confirmed cases is less than 10

# %%
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df[df.Confirmed<10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
df=df[~(df.Confirmed<10)]

# %%
df[df.Confirmed<10]
# Out:
# Empty DataFrame
# Columns: [Date, Region, Confirmed, Deaths, Recovered]
# Index: []

# %% [markdown]
# # Q3)In which region ,maximum no. of confirmed cases were recorded ??

# %%
df.groupby('Region').Confirmed.sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q3)In which region ,minimum no. of Deaths cases were recorded ??

# %%
df.groupby('Region').Deaths.sum().sort_values().head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# # Q5) How many confirmed Deaths and Recovered cases were reported from India till 29 April 2020 ?

# %%
df[df.Region=='India']
# Out:
#          Date Region  Confirmed  Deaths  Recovered
# 74  4/29/2020  India      33062    1079       8437

# %% [markdown]
# # Q6-A) Sort the entire data wrt no. of Confirmed cases in ascending order

# %%
df.sort_values(by=['Confirmed'])
# Out:
#           Date    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020  Suriname         10       1          8
# 70   4/29/2020  Holy See         10       0          2
# 59   4/29/2020    Gambia         10       1          8
# 318  4/29/2020    Canada         11       0          0
# 217  4/29/2020   Denmark         11       0         11
# ..         ...       ...        ...     ...        ...
# 57   4/29/2020    France     165093   24087      48228
# 168  4/29/2020        UK     165221   26097          0
# 80   4/29/2020     Italy     203591   27682      71252
# 153  4/29/2020     Spain     236899   24275     132929
# 265  4/29/2020        US     299691   23477          0
#
# [304 rows x 5 columns]

# %% [markdown]
# # Q6-B) Sort the entire data wrt no. of Recovered cases in descending order

# %%
df.sort_values(by=['Recovered'],ascending=False)
# Out:
#           Date          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020           Spain     236899   24275     132929
# 61   4/29/2020         Germany     161539    6467     120400
# 76   4/29/2020            Iran      93657    5957      73791
# 80   4/29/2020           Italy     203591   27682      71252
# 229  4/29/2020  Mainland China      68128    4512      63616
# ..         ...             ...        ...     ...        ...
# 258  4/29/2020              US       4934     230          0
# 257  4/29/2020              US       3851      56          0
# 255  4/29/2020              US        451      16          0
# 254  4/29/2020              US       7660     338          0
# 274  4/29/2020              US      17303     937          0
#
# [304 rows x 5 columns]
