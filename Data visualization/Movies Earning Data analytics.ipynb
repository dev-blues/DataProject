# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
df=pd.read_csv('movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
dff=df.dropna()

# %%
dff.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
#changing the datatypes of the columns

dff['budget']=dff['budget'].astype('int64')
dff['gross']=dff['gross'].astype('int64')
# Out:
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\926958277.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['budget']=dff['budget'].astype('int64')
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\926958277.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['gross']=dff['gross'].astype('int64')

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   rating    5421 non-null   object
#  2   genre     5421 non-null   object
#  3   year      5421 non-null   int64
#  4   released  5421 non-null   object
#  5   score     5421 non-null   float64
#  6   votes     5421 non-null   float64
#  7   director  5421 non-null   object
#  8   writer    5421 non-null   object
#  9   star      5421 non-null   object
#  10  country   5421 non-null   object
#  11  budget    5421 non-null   int64
#  12  gross     5421 non-null   int64
#  13  company   5421 non-null   object
#  14  runtime   5421 non-null   float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 677.6+ KB

# %%
dff.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Splittng released released column into release_date & release_country

dff[['released_date','released_country']]=dff['released'].str.split('(',expand=True)
# Out:
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\1813917895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff[['released_date','released_country']]=dff['released'].str.split('(',expand=True)
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\1813917895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff[['released_date','released_country']]=dff['released'].str.split('(',expand=True)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              5421 non-null   object
#  1   rating            5421 non-null   object
#  2   genre             5421 non-null   object
#  3   year              5421 non-null   int64
#  4   released          5421 non-null   object
#  5   score             5421 non-null   float64
#  6   votes             5421 non-null   float64
#  7   director          5421 non-null   object
#  8   writer            5421 non-null   object
#  9   star              5421 non-null   object
#  10  country           5421 non-null   object
#  11  budget            5421 non-null   int64
#  12  gross             5421 non-null   int64
#  13  company           5421 non-null   object
#  14  runtime           5421 non-null   float64
#  15  released_date     5421 non-null   object
# ...

# %%
# Deleting released column

dff.drop('released',axis=1, inplace=True)
# Out:
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\68754559.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.drop('released',axis=1, inplace=True)

# %%
pd.set_option('display.max_rows',None)

# %%
#Checking highly grossing movies

dff.sort_values(by='gross',inplace=True,ascending=False)
dff
# Out:
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\3025210609.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.sort_values(by='gross',inplace=True,ascending=False)
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# ...

# %%
# Scatter plot with budget vs gross
style.use('ggplot')
plt.figure(figsize=(10,5))

plt.scatter(x=dff['budget'], y=dff['gross'],cmap='pla51465816')

plt.xlabel('Budget for Film',fontsize=15)
plt.ylabel('Gross Earnings',fontsize=15)
plt.title('Budget vs Gross',fontsize=20)

plt.show()

# %%
#Plot budget vs gross using seaborn

plt.figure(figsize=(10,5))

sns.regplot(x=dff['budget'], y=dff['gross'],
       scatter_kws={'color':'#00C957'},
       line_kws={'color':'#104E8B'})

plt.xlabel('Budget for Film',fontsize=15)
plt.ylabel('Gross Earnings',fontsize=15)
plt.title('Budget vs Gross',fontsize=20)

plt.show()

# %%
dff.corr(method='pearson') #pearson, kendall, spearson
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#High correlation b/w budget and gross

# %%
correlation_matrix=dff.corr(method='pearson')
plt.figure(figsize=(10,5))

sns.heatmap(correlation_matrix,annot=True,)

plt.xlabel('Movie Features',fontsize=10)
plt.ylabel('Movie Features',fontsize=10)
plt.title('Correlation Matric for Numeric Features',fontsize=10)
plt.show()

# %%
dff.head()
# Out:
#                                             name rating   genre  year  score  \
# 5445                                      Avatar  PG-13  Action  2009    7.8
# 7445                           Avengers: Endgame  PG-13  Action  2019    8.4
# 3045                                     Titanic  PG-13   Drama  1997    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015    7.8
# 7244                      Avengers: Infinity War  PG-13  Action  2018    8.4
#
#           votes       director              writer               star  \
# 5445  1100000.0  James Cameron       James Cameron    Sam Worthington
# 7445   903000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000.0  James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000.0    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country     budget       gross                company  runtime  \
# ...

# %%
#changing Company datatype to random numeric value 
df_numerise=dff

for col_name in df_numerise.columns:
    if(df_numerise[col_name].dtype=='object'):
        df_numerise[col_name]=df_numerise[col_name].astype('category')
        df_numerise[col_name]=df_numerise[col_name].cat.codes #to give numeric value
        
df_numerise.head()
# Out:
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\3826720723.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numerise[col_name]=df_numerise[col_name].astype('category')
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\3826720723.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numerise[col_name]=df_numerise[col_name].cat.codes #to give numeric value
# C:\Users\Dev\AppData\Local\Temp\ipykernel_14076\3826720723.py:6: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
correlation_matrix=df_numerise.corr(method='pearson')
plt.figure(figsize=(16,9))

sns.heatmap(correlation_matrix,annot=True,)

plt.xlabel('Movie Features',fontsize=10)
plt.ylabel('Movie Features',fontsize=10)
plt.title('Correlation Matric for Numeric Features',fontsize=10)
plt.show()

# %%
df_numerise.corr()
# Out:
#                       name    rating     genre      year     score     votes  \
# name              1.000000 -0.029234  0.010996  0.025542  0.014450  0.012615
# rating           -0.029234  1.000000  0.147796  0.019499  0.065983  0.006031
# genre             0.010996  0.147796  1.000000 -0.073167  0.035106 -0.135990
# year              0.025542  0.019499 -0.073167  1.000000  0.056386  0.206021
# score             0.014450  0.065983  0.035106  0.056386  1.000000  0.474256
# votes             0.012615  0.006031 -0.135990  0.206021  0.474256  1.000000
# director          0.015246  0.014656 -0.008553 -0.038354  0.005413 -0.010376
# writer            0.012880 -0.003149  0.017578 -0.025908  0.012843 -0.005316
# star             -0.006882  0.009196  0.003341 -0.032157  0.007296 -0.017638
# country          -0.025490  0.008230 -0.009164 -0.066748 -0.043051  0.041551
# budget            0.023392 -0.203946 -0.368523  0.327722  0.072001  0.439675
# ...

# %%
correlation_mat=df_numerise.corr()

corr_pairs=correlation_mat.unstack()

corr_pairs
# Out:
# name              name                1.000000
#                   rating             -0.029234
#                   genre               0.010996
#                   year                0.025542
#                   score               0.014450
#                   votes               0.012615
#                   director            0.015246
#                   writer              0.012880
#                   star               -0.006882
#                   country            -0.025490
#                   budget              0.023392
#                   gross               0.005639
#                   company             0.021697
#                   runtime             0.010850
#                   released_date      -0.006155
#                   released_country   -0.002908
# rating            name               -0.029234
#                   rating              1.000000
#                   genre               0.147796
#                   year                0.019499
# ...

# %%
sorted_pairs= corr_pairs.sort_values()

sorted_pairs
# Out:
# genre             budget             -0.368523
# budget            genre              -0.368523
# gross             genre              -0.244101
# genre             gross              -0.244101
# rating            budget             -0.203946
# budget            rating             -0.203946
# gross             rating             -0.181906
# rating            gross              -0.181906
# votes             genre              -0.135990
# genre             votes              -0.135990
# company           rating             -0.092357
# rating            company            -0.092357
# genre             released_country   -0.075552
# released_country  genre              -0.075552
# genre             year               -0.073167
# year              genre              -0.073167
# company           genre              -0.071334
# genre             company            -0.071334
# country           year               -0.066748
# year              country            -0.066748
# ...

# %%
high_corr= sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# gross             votes               0.614751
# votes             gross               0.614751
# budget            gross               0.740247
# gross             budget              0.740247
# name              name                1.000000
# runtime           runtime             1.000000
# company           company             1.000000
# gross             gross               1.000000
# budget            budget              1.000000
# country           country             1.000000
# star              star                1.000000
# writer            writer              1.000000
# director          director            1.000000
# votes             votes               1.000000
# score             score               1.000000
# year              year                1.000000
# genre             genre               1.000000
# rating            rating              1.000000
# released_date     released_date       1.000000
# released_country  released_country    1.000000
# dtype: float64

# %%
#votes and budget have th highest correlation to gross earnings
#Company has low correlation
#we were wrong
